# %%
import notebookutils
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 3, Finished, Available, Finished)

# %%
notebookutils.help()
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 4, Finished, Available, Finished)
# ...

# %%
notebookutils.fs.help()
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 5, Finished, Available, Finished)
# <b> notebookutils.fs </b> provides utilities for working with various FileSystems. <br/><br/>
# Below is overview about the available methods: <br/><br/>
# <b> cp(from: String, to: String, recurse: Boolean = false): Boolean </b>
# -> Copies a file or directory, possibly across FileSystems <br/>
# <b> fastcp(from: String, to: String, recurse: Boolean = true): Boolean </b>
# -> Copies a file or directory via azcopy, possibly across FileSystems. <br/>
# <b> mv(from: String, to: String, createPath: Boolean = false,
# overwrite: Boolean = false): Boolean </b>
# -> Moves a file or directory, possibly across FileSystems <br/>
# <b> ls(dir: String): Array </b>
# -> Lists the contents of a directory <br/>
# <b> mkdirs(dir: String): Boolean </b>
# -> Creates the given directory if it does not exist, also creating any
# necessary parent directories <br/>
# ...

# %% [markdown]
# **fs ls**

# %%
for i in notebookutils.fs.ls("Files/"):

    print(i.path)
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 12, Finished, Available, Finished)
# abfss://b0e18415-11ac-44cf-b93b-75ae41ec8d36@onelake.dfs.fabric.microsoft.com/912a529f-4ae0-47f7-b16a-8e52bd194897/Files/AzureDataIngestion
# abfss://b0e18415-11ac-44cf-b93b-75ae41ec8d36@onelake.dfs.fabric.microsoft.com/912a529f-4ae0-47f7-b16a-8e52bd194897/Files/azure_raw_csv
# abfss://b0e18415-11ac-44cf-b93b-75ae41ec8d36@onelake.dfs.fabric.microsoft.com/912a529f-4ae0-47f7-b16a-8e52bd194897/Files/my_data
# abfss://b0e18415-11ac-44cf-b93b-75ae41ec8d36@onelake.dfs.fabric.microsoft.com/912a529f-4ae0-47f7-b16a-8e52bd194897/Files/olist_customers_dataset.csv
# abfss://b0e18415-11ac-44cf-b93b-75ae41ec8d36@onelake.dfs.fabric.microsoft.com/912a529f-4ae0-47f7-b16a-8e52bd194897/Files/schema_folder
# abfss://b0e18415-11ac-44cf-b93b-75ae41ec8d36@onelake.dfs.fabric.microsoft.com/912a529f-4ae0-47f7-b16a-8e52bd194897/Files/source_fabric
# ...

# %% [markdown]
# **cp**

# %%
notebookutils.fs.cp("Files/azure_raw_csv/olist_products_dataset.parquet","Files/my_data")
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 13, Finished, Available, Finished)
# True

# %% [markdown]
# **fast cp**

# %%
notebookutils.fs.fastcp("Files/azure_raw_csv/olist_products_dataset.parquet","Files/source_fabric/olist_products_dataset.parquet")
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 15, Finished, Available, Finished)
# True

# %% [markdown]
# **mv**

# %%
notebookutils.fs.mv("Files/source_fabric/olist_products_dataset.parquet","Files/schema_folder/olist_products_dataset.parquet")
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 16, Finished, Available, Finished)
# True

# %% [markdown]
# **rm**

# %%
notebookutils.fs.rm("Files/schema_folder/olist_products_dataset.parquet")
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 18, Finished, Available, Finished)
# True

# %% [markdown]
# **mkdirs**

# %%
notebookutils.fs.mkdirs("Files/newfolder")
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 19, Finished, Available, Finished)
# True

# %% [markdown]
# **put**

# %%
notebookutils.fs.put("Files/newfolder/newfile.txt","I love Fabric")
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 20, Finished, Available, Finished)
# True

# %%
notebookutils.notebook.help()
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 21, Finished, Available, Finished)
# The notebook module. <br/><br/>
# <b> exit(value: String): void </b> ->
# This method lets you exit a notebook with a value. <br/>
# <b> run(path: String, timeoutSeconds: int, arguments: Map, workspace: String): String </b>
# -> This method runs a notebook and returns its exit value. <br/><br/>
# <b> runMultiple(DAG: Any): Map[String, MsNotebookRunResult] </b>
# -> Runs multiple notebooks concurrently with support for dependency relationships.
# <br/>
# <b> validateDAG(DAG: Any): Boolean </b>
# -> This method check if the DAG is correctly defined. <br/><br/>
# <displayInFabric>
# <b> create(name: String, description: String = "", content: String = "",
#  defaultLakehouse: String = "", defaultLakehouseWorkspace: String = "",
#  workspaceId: String = ""): Artifact </b>
# -> Create a new Notebook. <br/>
# <b> get(name: String, workspaceId: String = ""): Artifact </b>
# ...

# %%
my_var = notebookutils.notebook.run("runNotebook",100,{"p_name":"Ansh Lamba"})
print(my_var)
# Out:
# StatementMeta(, 5d707ed0-c32d-470c-838d-0aa681648fb1, 25, Finished, Available, Finished)
# Bye -Bye Ansh Lamba
