-- %% [markdown]
-- **QUERYING**

-- %%
SELECT * FROM ansh_DWH.gold.cur_customers

-- %% [markdown]
-- **DDL**

-- %%
CREATE TABLE dbo.notebook_table
(
    id INT,
    name VARCHAR(100),
    salary INT 
)
