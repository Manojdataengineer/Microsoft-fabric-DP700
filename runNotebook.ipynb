# %%
import notebookutils
# Out:
# StatementMeta(, 462f4656-abe7-4986-af3e-cca8985fa513, 3, Finished, Available, Finished)

# %%
print("Hello Ansh")
# Out:
# StatementMeta(, 462f4656-abe7-4986-af3e-cca8985fa513, 4, Finished, Available, Finished)
# Hello Ansh

# %%
p_name = "Ansh"
# Out:
# StatementMeta(, 462f4656-abe7-4986-af3e-cca8985fa513, 5, Finished, Available, Finished)

# %%
notebookutils.notebook.exit(f"Bye -Bye {p_name}")
# Out:
# StatementMeta(, 462f4656-abe7-4986-af3e-cca8985fa513, 6, Finished, Available, Finished)
# ExitValue: Bye -Bye Ansh
