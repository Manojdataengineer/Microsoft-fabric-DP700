# %%
# %%pyspark
# import env.secret as my_secret

# %%
# %%pyspark
# print(my_secret.my_secret)

# %%
df = spark.read.parquet("Files/source_parquet_file/part-00000-tid-1594937361632335988-9e00517f-de1c-480a-8541-bc8539c0b95c-12-1-c000.snappy.parquet")
# df now is a Spark DataFrame containing parquet data from "Files/source_parquet_file/part-00000-tid-1594937361632335988-9e00517f-de1c-480a-8541-bc8539c0b95c-12-1-c000.snappy.parquet".
display(df)
# Out:
# StatementMeta(, 1b81baf5-8b16-40f7-bb9f-68b5fa5bb4f4, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 28d0c180-7916-445f-b5d1-93486a46db11)

# %%
df.printSchema()
# Out:
# StatementMeta(, 1b81baf5-8b16-40f7-bb9f-68b5fa5bb4f4, 4, Finished, Available, Finished)
# root
#  |-- Branch_ID: string (nullable = true)
#  |-- Dealer_ID: string (nullable = true)
#  |-- Model_ID: string (nullable = true)
#  |-- Revenue: long (nullable = true)
#  |-- Units_Sold: long (nullable = true)
#  |-- Date_ID: string (nullable = true)
#  |-- Day: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- BranchName: string (nullable = true)
#  |-- DealerName: string (nullable = true)
#  |-- model_category: string (nullable = true)
#  |-- RevPerUnit: double (nullable = true)
